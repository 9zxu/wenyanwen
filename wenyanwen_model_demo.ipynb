# %% [markdown]
# # Tokenization and Part-of-Speech
#
# `hanlp` documentation of
# - [tok](https://hanlp.hankcs.com/docs/api/hanlp/pretrained/tok.html)
# - [pos](https://hanlp.hankcs.com/docs/api/hanlp/pretrained/pos.html)

# %%
# !pip install hanlp
# Out:
# Collecting hanlp
#   Downloading hanlp-2.1.3-py3-none-any.whl.metadata (13 kB)
# Collecting hanlp-common>=0.0.23 (from hanlp)
#   Downloading hanlp_common-0.0.23.tar.gz (28 kB)
#   Preparing metadata (setup.py) ... done
# Collecting hanlp-downloader (from hanlp)
#   Downloading hanlp_downloader-0.0.25.tar.gz (13 kB)
#   Preparing metadata (setup.py) ... done
# Collecting hanlp-trie>=0.0.4 (from hanlp)
#   Downloading hanlp_trie-0.0.5.tar.gz (6.7 kB)
#   Preparing metadata (setup.py) ... done
# Collecting pynvml (from hanlp)
#   Downloading pynvml-13.0.1-py3-none-any.whl.metadata (5.6 kB)
# Requirement already satisfied: sentencepiece>=0.1.91 in /usr/local/lib/python3.12/dist-packages (from hanlp) (0.2.1)
# Requirement already satisfied: termcolor in /usr/local/lib/python3.12/dist-packages (from hanlp) (3.3.0)
# Collecting toposort==1.5 (from hanlp)
#   Downloading toposort-1.5-py2.py3-none-any.whl.metadata (5.7 kB)
# Requirement already satisfied: torch>=1.6.0 in /usr/local/lib/python3.12/dist-packages (from hanlp) (2.9.0+cpu)
# Requirement already satisfied: transformers>=4.1.1 in /usr/local/lib/python3.12/dist-packages (from hanlp) (4.57.3)
# Collecting phrasetree>=0.0.9 (from hanlp-common>=0.0.23->hanlp)
#   Downloading phrasetree-0.0.9.tar.gz (42 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 42.2/42.2 kB 3.2 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: filelock in /usr/local/lib/python3.12/dist-packages (from torch>=1.6.0->hanlp) (3.20.2)
# Requirement already satisfied: typing-extensions>=4.10.0 in /usr/local/lib/python3.12/dist-packages (from torch>=1.6.0->hanlp) (4.15.0)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.12/dist-packages (from torch>=1.6.0->hanlp) (75.2.0)
# Requirement already satisfied: sympy>=1.13.3 in /usr/local/lib/python3.12/dist-packages (from torch>=1.6.0->hanlp) (1.14.0)
# Requirement already satisfied: networkx>=2.5.1 in /usr/local/lib/python3.12/dist-packages (from torch>=1.6.0->hanlp) (3.6.1)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.12/dist-packages (from torch>=1.6.0->hanlp) (3.1.6)
# Requirement already satisfied: fsspec>=0.8.5 in /usr/local/lib/python3.12/dist-packages (from torch>=1.6.0->hanlp) (2025.3.0)
# Requirement already satisfied: huggingface-hub<1.0,>=0.34.0 in /usr/local/lib/python3.12/dist-packages (from transformers>=4.1.1->hanlp) (0.36.0)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.12/dist-packages (from transformers>=4.1.1->hanlp) (2.0.2)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.12/dist-packages (from transformers>=4.1.1->hanlp) (25.0)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.12/dist-packages (from transformers>=4.1.1->hanlp) (6.0.3)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.12/dist-packages (from transformers>=4.1.1->hanlp) (2025.11.3)
# Requirement already satisfied: requests in /usr/local/lib/python3.12/dist-packages (from transformers>=4.1.1->hanlp) (2.32.4)
# Requirement already satisfied: tokenizers<=0.23.0,>=0.22.0 in /usr/local/lib/python3.12/dist-packages (from transformers>=4.1.1->hanlp) (0.22.2)
# Requirement already satisfied: safetensors>=0.4.3 in /usr/local/lib/python3.12/dist-packages (from transformers>=4.1.1->hanlp) (0.7.0)
# Requirement already satisfied: tqdm>=4.27 in /usr/local/lib/python3.12/dist-packages (from transformers>=4.1.1->hanlp) (4.67.1)
# Collecting nvidia-ml-py>=12.0.0 (from pynvml->hanlp)
#   Downloading nvidia_ml_py-13.590.44-py3-none-any.whl.metadata (9.8 kB)
# Requirement already satisfied: hf-xet<2.0.0,>=1.1.3 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub<1.0,>=0.34.0->transformers>=4.1.1->hanlp) (1.2.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.12/dist-packages (from sympy>=1.13.3->torch>=1.6.0->hanlp) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.12/dist-packages (from jinja2->torch>=1.6.0->hanlp) (3.0.3)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests->transformers>=4.1.1->hanlp) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests->transformers>=4.1.1->hanlp) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests->transformers>=4.1.1->hanlp) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests->transformers>=4.1.1->hanlp) (2026.1.4)
# Downloading hanlp-2.1.3-py3-none-any.whl (654 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 654.1/654.1 kB 14.0 MB/s eta 0:00:00
# Downloading toposort-1.5-py2.py3-none-any.whl (7.6 kB)
# Downloading pynvml-13.0.1-py3-none-any.whl (28 kB)
# Downloading nvidia_ml_py-13.590.44-py3-none-any.whl (50 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 50.7/50.7 kB 3.1 MB/s eta 0:00:00
# Building wheels for collected packages: hanlp-common, hanlp-trie, hanlp-downloader, phrasetree
#   Building wheel for hanlp-common (setup.py) ... done
#   Created wheel for hanlp-common: filename=hanlp_common-0.0.23-py3-none-any.whl size=30819 sha256=ecca4005cd6f285137dc0906dac99c0ffb4ceb395cd815a333924da431a1e5f2
#   Stored in directory: /root/.cache/pip/wheels/b8/22/2d/75d505250ca2b83d52998e97db4d3ed89315138752d2e22794
#   Building wheel for hanlp-trie (setup.py) ... done
#   Created wheel for hanlp-trie: filename=hanlp_trie-0.0.5-py3-none-any.whl size=6816 sha256=5233742f6d59eb626506df9ee61d907ba82fc2c83164eddf3bb9271e57dd50ea
#   Stored in directory: /root/.cache/pip/wheels/26/a2/e2/b2a458cadfb9ff912848b0e6205bfa5ac628daa5156ccac651
#   Building wheel for hanlp-downloader (setup.py) ... done
#   Created wheel for hanlp-downloader: filename=hanlp_downloader-0.0.25-py3-none-any.whl size=13746 sha256=0b75a847b84cd673c1c9e7e71fe7fd8ad3910c46216f30c1e4a4b67275d5a4ef
#   Stored in directory: /root/.cache/pip/wheels/f6/59/2c/1373729f96160c9cded2968f6c33377aab5c95ba1002b559fd
#   Building wheel for phrasetree (setup.py) ... done
#   Created wheel for phrasetree: filename=phrasetree-0.0.9-py3-none-any.whl size=44218 sha256=e692ecdcc58e2be2e5e6876e51bb71b4de401ad4c3bb2e33147d0c78264ce8b2
#   Stored in directory: /root/.cache/pip/wheels/85/6c/77/51fc144dbf90ff2b9e898ce24082958e63388341de3567ace3
# Successfully built hanlp-common hanlp-trie hanlp-downloader phrasetree
# Installing collected packages: toposort, phrasetree, nvidia-ml-py, pynvml, hanlp-common, hanlp-trie, hanlp-downloader, hanlp
# Successfully installed hanlp-2.1.3 hanlp-common-0.0.23 hanlp-downloader-0.0.25 hanlp-trie-0.0.5 nvidia-ml-py-13.590.44 phrasetree-0.0.9 pynvml-13.0.1 toposort-1.5

# %%
import hanlp
tok = hanlp.load(hanlp.pretrained.tok.COARSE_ELECTRA_SMALL_ZH)
pos = hanlp.load(hanlp.pretrained.pos.CTB9_POS_ELECTRA_SMALL)
# Out:
# Downloading https://file.hankcs.com/hanlp/tok/coarse_electra_small_20220616_012050.zip to /root/.hanlp/tok/coarse_electra_small_20220616_012050.zip
# 100%  43.5 MiB 891.2 KiB/s ETA:  0 s [=========================================]
# Decompressing /root/.hanlp/tok/coarse_electra_small_20220616_012050.zip to /root/.hanlp/tok
# WARNING:torchao.kernel.intmm:Warning: Detected no triton, on systems without Triton certain kernels will not work
# Downloading https://file.hankcs.com/hanlp/utils/char_table_20210602_202632.json.zip to /root/.hanlp/utils/char_table_20210602_202632.json.zip
# 100%  26.7 KiB   6.7 KiB/s ETA:  0 s [=========================================]
# Decompressing /root/.hanlp/utils/char_table_20210602_202632.json.zip to /root/.hanlp/utils
# Downloading https://file.hankcs.com/hanlp/transformers/electra_zh_small_20210706_125427.zip to /root/.hanlp/transformers/electra_zh_small_20210706_125427.zip
# 100%  41.2 KiB  41.2 KiB/s ETA:  0 s [=========================================]
# Decompressing /root/.hanlp/transformers/electra_zh_small_20210706_125427.zip to /root/.hanlp/transformers
# Downloading https://file.hankcs.com/hanlp/pos/pos_ctb_electra_small_20220215_111944.zip to /root/.hanlp/pos/pos_ctb_electra_small_20220215_111944.zip
# 100%  43.5 MiB 123.0 KiB/s ETA:  0 s [=========================================]
# Decompressing /root/.hanlp/pos/pos_ctb_electra_small_20220215_111944.zip to /root/.hanlp/pos

# %%
test = [
    '師者，所以傳道、受業、解惑也',
    '故人西辭黃鶴樓，煙花三月下揚州。孤帆遠影碧空盡，惟見長江天際流。',
    '商品和服务。',
    '晓美焰来到北京立方庭参观自然语义科技公司'
]

# %%
tok_test = tok(test)
for i in tok_test:
  print(i)
# Out:
# ['師', '者', '，', '所以', '傳道', '、', '受業', '、', '解惑', '也']
# ['故人', '西', '辭', '黃鶴樓', '，', '煙花', '三月', '下', '揚州', '。', '孤', '帆', '遠', '影', '碧空', '盡', '，', '惟', '見', '長江', '天際', '流', '。']
# ['商品', '和', '服务', '。']
# ['晓美焰', '来到', '北京立方庭', '参观', '自然语义科技公司']

# %%
for i in tok_test:
  print(pos(i))
# Out:
# ['NN', 'SP', 'PU', 'AD', 'VV', 'PU', 'VV', 'PU', 'VV', 'SP']
# ['NN', 'NR', 'VV', 'NR', 'PU', 'NN', 'NT', 'VV', 'NR', 'PU', 'JJ', 'NN', 'JJ', 'NN', 'NN', 'VV', 'PU', 'AD', 'VV', 'NR', 'NN', 'VV', 'PU']
# ['NN', 'CC', 'NN', 'PU']
# ['NR', 'VV', 'NR', 'VV', 'NN']

# %% [markdown]
# # Text-to-speech

# %%
# !pip install edge-tts
# Out:
# Collecting edge-tts
#   Downloading edge_tts-7.2.7-py3-none-any.whl.metadata (5.5 kB)
# Requirement already satisfied: aiohttp<4.0.0,>=3.8.0 in /usr/local/lib/python3.12/dist-packages (from edge-tts) (3.13.3)
# Requirement already satisfied: certifi>=2023.11.17 in /usr/local/lib/python3.12/dist-packages (from edge-tts) (2026.1.4)
# Requirement already satisfied: tabulate<1.0.0,>=0.4.4 in /usr/local/lib/python3.12/dist-packages (from edge-tts) (0.9.0)
# Requirement already satisfied: typing-extensions<5.0.0,>=4.1.0 in /usr/local/lib/python3.12/dist-packages (from edge-tts) (4.15.0)
# Requirement already satisfied: aiohappyeyeballs>=2.5.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp<4.0.0,>=3.8.0->edge-tts) (2.6.1)
# Requirement already satisfied: aiosignal>=1.4.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp<4.0.0,>=3.8.0->edge-tts) (1.4.0)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp<4.0.0,>=3.8.0->edge-tts) (25.4.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.12/dist-packages (from aiohttp<4.0.0,>=3.8.0->edge-tts) (1.8.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.12/dist-packages (from aiohttp<4.0.0,>=3.8.0->edge-tts) (6.7.0)
# Requirement already satisfied: propcache>=0.2.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp<4.0.0,>=3.8.0->edge-tts) (0.4.1)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp<4.0.0,>=3.8.0->edge-tts) (1.22.0)
# Requirement already satisfied: idna>=2.0 in /usr/local/lib/python3.12/dist-packages (from yarl<2.0,>=1.17.0->aiohttp<4.0.0,>=3.8.0->edge-tts) (3.11)
# Downloading edge_tts-7.2.7-py3-none-any.whl (30 kB)
# Installing collected packages: edge-tts
# Successfully installed edge-tts-7.2.7

# %%
test = [
    '師者，所以傳道、受業、解惑也',
    '故人西辭黃鶴樓，煙花三月下揚州。孤帆遠影碧空盡，惟見長江天際流。',
    '商品和服务。',
    '晓美焰来到北京立方庭参观自然语义科技公司'
]

# %%
import edge_tts
import os

# Create the output directory if it doesn't exist
output_dir = "autio_out"
os.makedirs(output_dir, exist_ok=True)

for i in range(len(test)):
    communicate = edge_tts.Communicate(test[i], "zh-CN-YunjianNeural")
    await communicate.save(os.path.join(output_dir, f"test{i}.mp3"))

# %%
from IPython.display import Audio, display

for i in range(len(test)):
    sound_file = os.path.join(output_dir, f"test{i}.mp3")

    # Display the audio player in the output cell
    display(Audio(sound_file, autoplay=False))
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/mpeg;base64,..." type="audio/mpeg" />
#                     Your browser does not support the audio element.
#                 </audio>
#                 <audio  controls="controls" >
#                     <source src="data:audio/mpeg;base64,..." type="audio/mpeg" />
#                     Your browser does not support the audio element.
#                 </audio>
#                 <audio  controls="controls" >
#                     <source src="data:audio/mpeg;base64,..." type="audio/mpeg" />
#                     Your browser does not support the audio element.
#                 </audio>
#                 <audio  controls="controls" >
#                     <source src="data:audio/mpeg;base64,..." type="audio/mpeg" />
#                     Your browser does not support the audio element.
#                 </audio>
